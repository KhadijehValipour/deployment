# %%
import json
import requests

# %%
response = requests.get("https://www.fruityvice.com/api/fruit/peach")
response.status_code
# Out:
# 200

# %%
json.loads(response.text)
# Out:
# {'name': 'Peach',
#  'id': 86,
#  'family': 'Rosaceae',
#  'order': 'Rosales',
#  'genus': 'Prunus',
#  'nutritions': {'calories': 39,
#   'fat': 0.25,
#   'sugar': 8.4,
#   'carbohydrates': 9.5,
#   'protein': 0.9}}

# %%
response = requests.get("https://goweather.herokuapp.com/weather/Lamerd")
json.loads(response.text)
# Out:
# {'temperature': '+24 °C',
#  'wind': '18 km/h',
#  'description': 'Sunny',
#  'forecast': [{'day': '1', 'temperature': '+25 °C', 'wind': '21 km/h'},
#   {'day': '2', 'temperature': '+25 °C', 'wind': '11 km/h'},
#   {'day': '3', 'temperature': '+25 °C', 'wind': '14 km/h'}]}

# %%
response = requests.get("https://picsum.photos/200/300")
response.status_code
# Out:
# 200

# %%
response.content

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

file_data = np.frombuffer(response.content, dtype="int8")
image = cv2.imdecode(file_data, cv2.IMREAD_UNCHANGED)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %%
response = requests.get("https://thispersondoesnotexist.com")
response.status_code
# Out:
# 200

# %%
response.content

# %%
file_data2 = np.frombuffer(response.content, dtype="int8")
image2 = cv2.imdecode(file_data2, cv2.IMREAD_UNCHANGED)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
plt.imshow(image2)
plt.show()
